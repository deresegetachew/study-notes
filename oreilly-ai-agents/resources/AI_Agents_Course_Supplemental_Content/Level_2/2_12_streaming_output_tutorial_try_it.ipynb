# %% [markdown]
# # Streaming Output: Practice Exercise
#
# Implement streaming output using LangChain that displays an LLM response in real-time as it is generated.
#
# **What you'll implement:**
# - Initialize a LangChain `ChatOpenAI` model with streaming enabled
# - Use the `stream()` method to iterate through response chunks
# - Display content in real-time as it arrives
#
# **Estimated time:** 10 minutes

# %% [markdown]
# ## Setup
#
# Run this cell to load the required libraries and configure the environment.

# %%
# Setup - run this cell first

import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

print("Setup complete!")

# %% [markdown]
# ## Your Task
#
# Implement a function that streams an LLM response using LangChain.
#
# **Input:**
# - `prompt`: A string containing the user's prompt
#
# **Output:**
# - The function should print each chunk as it arrives (real-time display)
# - Return the complete response as a single string
#
# **Requirements:**
# 1. Initialize `ChatOpenAI` with `model="gpt-4o-mini"` and `streaming=True`
# 2. Use `llm.stream(prompt)` to get a streaming response
# 3. Iterate through chunks and print `chunk.content` with `end=""` and `flush=True`
# 4. Accumulate and return the full response

# %% [markdown]
# ## Implement the Streaming Function
#
# Complete the function below to stream a response using LangChain.

# %%
def stream_response(prompt: str) -> str:
    """
    Stream an LLM response using LangChain.
    
    Args:
        prompt: The user's prompt
    
    Returns:
        The complete response as a string
    """
    print("Assistant: ", end="", flush=True)
    
    # TODO 1: Initialize a ChatOpenAI model with model="gpt-4o-mini" and streaming=True
    
    # TODO 2: Use llm.stream(prompt) to get a streaming response
    # Iterate through the chunks, print chunk.content in real-time, and accumulate the full response
    
    full_response = ""
    
    pass
    
    print()  # New line at the end
    return full_response

# %% [markdown]
# ## Run Your Implementation
#
# Test your streaming function with different prompts.

# %%
# Test 1
response = stream_response("Explain what an API is in 2-3 sentences.")

print(f"\n--- Response length: {len(response)} characters ---")

# %%
# Test 2
response = stream_response("What are three benefits of using version control?")

print(f"\n--- Response length: {len(response)} characters ---")
